# %%
import pandas as pd

# %%
dff=pd.read_csv("ANSUR_II_FEMALE_Public.csv")
dfm=pd.read_csv("ANSUR_II_MALE_Public.csv")
print(dfm.info())
print(dff.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4082 entries, 0 to 4081
# Columns: 108 entries, subjectid to WritingPreference
# dtypes: int64(99), object(9)
# memory usage: 3.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Columns: 108 entries, SubjectId to WritingPreference
# dtypes: int64(99), object(9)
# memory usage: 1.6+ MB
# None

# %%
dfm.describe()
# Out:
#           subjectid  abdominalextensiondepthsitting  acromialheight  \
# count   4082.000000                     4082.000000     4082.000000
# mean   20003.370897                      254.650906     1440.736894
# std     6568.435122                       37.327178       63.287242
# min    10027.000000                      163.000000     1194.000000
# 25%    14270.250000                      227.000000     1398.000000
# 50%    17236.500000                      251.000000     1439.000000
# 75%    27315.750000                      279.000000     1481.000000
# max    29452.000000                      451.000000     1683.000000
#
#        acromionradialelength  anklecircumference  axillaheight  \
# count            4082.000000         4082.000000   4082.000000
# mean              335.244488          229.343949   1329.082068
# std                17.482795           14.649102     59.516123
# min               270.000000          156.000000   1106.000000
# ...

# %%
df=pd.concat([dff,dfm])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6068 entries, 0 to 4081
# Columns: 109 entries, SubjectId to subjectid
# dtypes: float64(2), int64(98), object(9)
# memory usage: 5.1+ MB

# %%
df.drop(columns=["subjectid"], inplace=True)
df.columns
# Out:
# Index(['SubjectId', 'abdominalextensiondepthsitting', 'acromialheight',
#        'acromionradialelength', 'anklecircumference', 'axillaheight',
#        'balloffootcircumference', 'balloffootlength', 'biacromialbreadth',
#        'bicepscircumferenceflexed',
#        ...
#        'Branch', 'PrimaryMOS', 'SubjectsBirthLocation', 'SubjectNumericRace',
#        'Ethnicity', 'DODRace', 'Age', 'Heightin', 'Weightlbs',
#        'WritingPreference'],
#       dtype='object', length=108)

# %%
print(df.columns.values)
# Out:
# ['SubjectId' 'abdominalextensiondepthsitting' 'acromialheight'
#  'acromionradialelength' 'anklecircumference' 'axillaheight'
#  'balloffootcircumference' 'balloffootlength' 'biacromialbreadth'
#  'bicepscircumferenceflexed' 'bicristalbreadth' 'bideltoidbreadth'
#  'bimalleolarbreadth' 'bitragionchinarc' 'bitragionsubmandibulararc'
#  'bizygomaticbreadth' 'buttockcircumference' 'buttockdepth'
#  'buttockheight' 'buttockkneelength' 'buttockpopliteallength'
#  'calfcircumference' 'cervicaleheight' 'chestbreadth' 'chestcircumference'
#  'chestdepth' 'chestheight' 'crotchheight' 'crotchlengthomphalion'
#  'crotchlengthposterioromphalion' 'earbreadth' 'earlength' 'earprotrusion'
#  'elbowrestheight' 'eyeheightsitting' 'footbreadthhorizontal' 'footlength'
#  'forearmcenterofgriplength' 'forearmcircumferenceflexed'
#  'forearmforearmbreadth' 'forearmhandlength' 'functionalleglength'
#  'handbreadth' 'handcircumference' 'handlength' 'headbreadth'
# ...

# %%
dff1=dff[["Heightin","handcircumference","Branch","Gender"]]
dff1.describe(include="all")
# Out:
#            Heightin  handcircumference                  Branch  Gender
# count   1986.000000        1986.000000                    1986    1986
# unique          NaN                NaN                       3       1
# top             NaN                NaN  Combat Service Support  Female
# freq            NaN                NaN                    1256    1986
# mean      64.601712         186.550352                     NaN     NaN
# std        2.801938           8.819987                     NaN     NaN
# min       56.000000         152.000000                     NaN     NaN
# 25%       63.000000         180.000000                     NaN     NaN
# 50%       64.000000         187.000000                     NaN     NaN
# 75%       66.000000         192.000000                     NaN     NaN
# max       80.000000         214.000000                     NaN     NaN

# %%
dffrn=dff1.rename(columns={"Heightin":"Höjdin", "Branch":"Enhet"})

# %%
dffrn
# Out:
#       Höjdin  handcircumference                   Enhet  Gender
# 0         61                182          Combat Support  Female
# 1         64                187  Combat Service Support  Female
# 2         68                198  Combat Service Support  Female
# 3         66                192  Combat Service Support  Female
# 4         63                183             Combat Arms  Female
# ...      ...                ...                     ...     ...
# 1981      67                197          Combat Support  Female
# 1982      63                196          Combat Support  Female
# 1983      66                192          Combat Support  Female
# 1984      63                177          Combat Support  Female
# 1985      66                187          Combat Support  Female
#
# [1986 rows x 4 columns]

# %%
dffrn["Höjd cm"]=dffrn["Höjdin"]*2.54
dffrn
# Out:
#       Höjdin  handcircumference                   Enhet  Gender  Höjd cm
# 0         61                182          Combat Support  Female   154.94
# 1         64                187  Combat Service Support  Female   162.56
# 2         68                198  Combat Service Support  Female   172.72
# 3         66                192  Combat Service Support  Female   167.64
# 4         63                183             Combat Arms  Female   160.02
# ...      ...                ...                     ...     ...      ...
# 1981      67                197          Combat Support  Female   170.18
# 1982      63                196          Combat Support  Female   160.02
# 1983      66                192          Combat Support  Female   167.64
# 1984      63                177          Combat Support  Female   160.02
# 1985      66                187          Combat Support  Female   167.64
#
# [1986 rows x 5 columns]

# %%
dffrn[dffrn["Enhet"]=="Combat Support"]
# Out:
#       Höjdin  handcircumference           Enhet  Gender  Höjd cm
# 0         61                182  Combat Support  Female   154.94
# 15        66                193  Combat Support  Female   167.64
# 17        67                178  Combat Support  Female   170.18
# 20        60                180  Combat Support  Female   152.40
# 21        66                185  Combat Support  Female   167.64
# ...      ...                ...             ...     ...      ...
# 1981      67                197  Combat Support  Female   170.18
# 1982      63                196  Combat Support  Female   160.02
# 1983      66                192  Combat Support  Female   167.64
# 1984      63                177  Combat Support  Female   160.02
# 1985      66                187  Combat Support  Female   167.64
#
# [687 rows x 5 columns]
